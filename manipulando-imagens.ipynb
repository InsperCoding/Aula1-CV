# %% [markdown]
# # Imagens Em Python - InsperCoding

# %% [markdown]
# ## Importando Bibliotecas Necessárias

# %%
# %matplotlib inline
import auxiliary as aux # biblioteca auxiliar
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print("OpenCV Version : %s " % cv2.__version__)
# Out:
# OpenCV Version : 4.5.3-dev

# %% [markdown]
# ## Exercício 1

# %% [markdown]
# ### Imagem Original

# %%
rintin = cv2.imread("img/RinTinTin.jpg")
rintin.shape
# Out:
# (239, 318, 3)

# %%
plt.imshow(rintin, vmin=0, vmax=255);

# %% [markdown]
# ### Imagem em GRAYSCALE (preto e branco)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)
rintin_gray.shape
# Out:
# (239, 318)

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255);

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.figure(figsize=(15,5))
plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# -> Crie uma imagem derivada da imagem fornecida que use melhor a faixa dinâmica, ou seja, tenha o valor dos seus pixels distribuídos entre `0` e `255`.
#
# - **Trabalhe no arquivo ex1.py**

# %% [markdown]
# ## Exercício 2

# %% [markdown]
# ![ex2](img/cena_canto_sala.jpg "ex2")
#
# ### Vamos separar os canais R, G e B da imagem e analise seu histograma.

# %%
cena = cv2.imread("img/cena_canto_sala.jpg")
cena = cv2.cvtColor(cena, cv2.COLOR_BGR2RGB)
aux.plot_hists(cena, plt)

# %% [markdown]
# O que você deve fazer
#
# Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos. Você vai precisar usar manipulação de canais RGB. (use como referência os canais RGB apresentados em histogramas acima)
#
# dica: Tudo que é vermelho transforme para 255, ao contrário transforme em 0.
#
# - **Trabalhe no arquivo ex2.py**

# %% [markdown]
# ## Exercício 3

# %% [markdown]
# O leopardo das neves é um animal que se camufla muito bem em terreno pedregoso e seco. A imagem a seguir mostra este animal:
#
#
# ![ex3](img/snowleopard_red_blue_600_400.png "ex3")

# %% [markdown]
# Para nos ajudar a localizá-lo foram definidos quadrados de 3x3 azuis e vermelhos.
#
# O que você deve fazer:
# - Usando código encontrar onde está o quadrado vermelho e onde está o quadrado azul
# - Recortar a imagem usando os cantos definidos pelo quadrado vermelho e azul
# - Salvar a sub imagem contida no recorte
#
#
#
# - **Trabalhe no arquivo ex3.py**

# %% [markdown]
# ## Exercício 4

# %% [markdown]
# A imagem fornecida contém a bandeira da Antártida e a do Canadá:
#
# ![ex4](img/ant_canada_250_160.png "ex4")

# %% [markdown]
# O que deve ser feito:
# - Usando programação descobrir onde começa e termina a bandeira da Antártida
# - Recortar a sub imagem que é a bandeira da Antártida
# - Descobrir onde começa e termina a bandeira do Canadá
# - Recortar a sub imagme que é a bandeira do Canadá
#
#
# - **Trabalhe no arquivo ex4.py**
